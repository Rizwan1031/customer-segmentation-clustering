# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('modeling_data.pkl' , 'rb') as f:
    data = pickle.load(f)

wcss = data['wcss']
X_scaled = data['X_scaled']
X_numeric = data['X_numeric']
X = data['X']
kmeans = data['kmeans']
kmeans_2 = data['kmeans_2']
scaler = data['scaler']

# %%
color = ['red','blue','green','purple','yellow']
for i in range(5):
    plt.scatter(X_scaled[X['Clusters']==i , 0],
                X_scaled[X['Clusters']==i , 1],
                c=color[i] , label=f'Cluster {i}')
    plt.scatter(kmeans.cluster_centers_[:,0],
                kmeans.cluster_centers_[:,1],
                s=300, c ='black', marker='*')

# %%
pred_input = pd.DataFrame([[income, recency]], columns=['Income', 'Recency'])
pred = kmeans_2.predict(pred_input)

# %%
import streamlit as st

# %%
income = st.slider('Annual Income (k$)', 15, 150)
recency = st.slider('Recency', 0, 100)
pred_input = pd.DataFrame([[income, recency]], columns=['Income', 'Recency'])
pred = kmeans_2.predict(pred_input)
st.write(f'Customer Segment: Cluster {pred[0]}')
# Out:
# 2026-05-01 15:10:06.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 15:10:06.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 15:10:06.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 15:10:06.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 15:10:06.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 15:10:06.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-05-01 15:10:06.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
